# %%
import pandas as pd
import matplotlib as plt
import re
fb = pd.read_csv('nysu_10902_2019_research_right.csv')
politics = pd.read_csv('9th_legislator_promise.csv')

# %%
fb.head(1)
# Out:
#                             post_id          page_id page_name page_category  \
# 0  244784245612709_2052039854887130  244784245612709       陳學聖          政治人物
#
#                                              message story   type  \
# 0  鑒於中油觀塘案在環評大會迅速通關，原先專案小組考量對藻礁生態有重大影響，建議退回目的事業主管...   NaN  photo
#
#                                            permalink  \
# 0  https://www.facebook.com/244784245612709/posts...
#
#            created_time_gmt  created_time_taipei  ... link_name  \
# 0  2019-01-15T11:00:16+0000  2019-01-15T19:00:16  ...       NaN
#
#   link_description like_count  haha_count  love_count  angry_count  sad_count  \
# 0              NaN        144           0           0            0          0
#
#    wow_count  comment_count  share_count
# 0          0              6            5
#
# [1 rows x 21 columns]

# %%
lo=fb[fb.page_name=="林德福"]
lo.head(1)
# Out:
#                                 post_id          page_id page_name  \
# 19135  888230767933636_2145125488910818  888230767933636       林德福
#
#       page_category                                            message story  \
# 19135          政治人物  【永和帳務中心】\r\n\r\n新北市政府今（16日）舉辦「享．再一起生活節」青年社群交流成...   NaN
#
#        type                                          permalink  \
# 19135  link  https://www.facebook.com/888230767933636/posts...
#
#                created_time_gmt  created_time_taipei  ...  \
# 19135  2019-03-16T10:24:13+0000  2019-03-16T18:24:13  ...
#
#                    link_name  \
# 19135  永和帳務中心活化有成 未來擬轉型公托、托老
#
#                                         link_description like_count  \
# 19135  新北市政府今（16日）舉辦「享．再一起生活節」青年社群交流成果展，市長侯友宜、立委林德福、市...        159
#
#        haha_count  love_count  angry_count  sad_count  wow_count  \
# 19135           0           0            0          0          0
#
#        comment_count  share_count
# 19135              3            0
#
# [1 rows x 21 columns]

# %%
#爬到的最後一篇
lo[lo.created_time_taipei == max(lo.created_time_taipei)]
# Out:
#                                 post_id          page_id page_name  \
# 19342  888230767933636_2729328570490504  888230767933636       林德福
#
#       page_category                                            message story  \
# 19342          政治人物  【車隊 雙和遶境】\r\n\r\n選前最後一日，新北市長侯友宜特別陪伴德福，車隊在雙和遶境，...   NaN
#
#         type                                          permalink  \
# 19342  photo  https://www.facebook.com/888230767933636/posts...
#
#                created_time_gmt  created_time_taipei  ... link_name  \
# 19342  2020-01-10T09:31:18+0000  2020-01-10T17:31:18  ...  林德福貼文的相片
#
#       link_description like_count  haha_count  love_count  angry_count  \
# 19342              NaN        567           0           0            0
#
#        sad_count  wow_count  comment_count  share_count
# 19342          0          0             21           12
#
# [1 rows x 21 columns]

# %%
#爬到的第一篇
lo[lo.created_time_taipei == min(lo.created_time_taipei)]
# Out:
#                                 post_id          page_id page_name  \
# 19141  888230767933636_2128021767287857  888230767933636       林德福
#
#       page_category                                            message story  \
# 19141          政治人物  【台農發 虧損7000萬】\r\n\r\n今日立法院財委會質詢，我針對台農發公司成立2年多，...   NaN
#
#         type                                          permalink  \
# 19141  photo  https://www.facebook.com/888230767933636/posts...
#
#                created_time_gmt  created_time_taipei  ... link_name  \
# 19141  2019-03-04T08:22:18+0000  2019-03-04T16:22:18  ...       NaN
#
#       link_description like_count  haha_count  love_count  angry_count  \
# 19141              NaN        655           0           0            0
#
#        sad_count  wow_count  comment_count  share_count
# 19141          0          0             81           24
#
# [1 rows x 21 columns]

# %%
#讓我們來做個時間排序吧
lo['new_date'] = pd.to_datetime(lo['created_time_taipei']).dt.date
lo['month_year'] = pd.to_datetime(lo['new_date']).dt.to_period('M')
lo['post_hour']=pd.to_datetime(lo['created_time_taipei']).dt.hour
lo.head(1)
# Out:
# <ipython-input-43-793464da8639>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lo['new_date'] = pd.to_datetime(lo['created_time_taipei']).dt.date
# <ipython-input-43-793464da8639>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lo['month_year'] = pd.to_datetime(lo['new_date']).dt.to_period('M')
# <ipython-input-43-793464da8639>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lo['post_hour']=pd.to_datetime(lo['created_time_taipei']).dt.hour
#                                 post_id          page_id page_name  \
# 19135  888230767933636_2145125488910818  888230767933636       林德福
#
#       page_category                                            message story  \
# 19135          政治人物  【永和帳務中心】\r\n\r\n新北市政府今（16日）舉辦「享．再一起生活節」青年社群交流成...   NaN
#
#        type                                          permalink  \
# 19135  link  https://www.facebook.com/888230767933636/posts...
#
#                created_time_gmt  created_time_taipei  ... haha_count  \
# 19135  2019-03-16T10:24:13+0000  2019-03-16T18:24:13  ...          0
#
#       love_count angry_count  sad_count  wow_count  comment_count  \
# 19135          0           0          0          0              3
#
#        share_count    new_date  month_year  post_hour
# 19135            0  2019-03-16     2019-03         18
#
# [1 rows x 24 columns]

# %%
#整個月份的總量
results = lo.groupby('month_year').sum()
results
# Out:
#                       page_id  like_count  haha_count  love_count  \
# month_year
# 2019-03     11546999983137268        5809           0           0
# 2019-04     22205769198340900       22101           0           0
# 2019-05     26646923038009080        8069           0           0
# 2019-06     18652846126606356       11002           0           0
# 2019-07     21317538430407264        8710           0           0
# 2019-08     20429307662473628       16075           0           0
# 2019-09     18652846126606356        7612           0           0
# 2019-10     19541076894539992        8532           0           0
# 2019-11     14211692286938176        7068           0           0
# 2019-12     14211692286938176       11605           0           0
# 2020-01     12435230751070904        7762           0           0
#
#             angry_count  sad_count  wow_count  comment_count  share_count  \
# month_year
# 2019-03               0          0          0            509           85
# 2019-04               0          0          0           1035          291
# 2019-05               0          0          0            725          150
# 2019-06               0          0          0            306          298
# 2019-07               0          0          0            469          297
# 2019-08               0          0          0            444          342
# 2019-09               0          0          0            366          356
# 2019-10               0          0          0            327          239
# 2019-11               0          0          0            825          317
# 2019-12               0          0          0            671          277
# 2020-01               0          0          0            293          251
#
#             post_hour
# month_year
# 2019-03           211
# 2019-04           356
# 2019-05           409
# 2019-06           287
# 2019-07           332
# 2019-08           347
# 2019-09           323
# 2019-10           321
# 2019-11           210
# 2019-12           222
# 2020-01           196

# %%
results.index.name = 'newhead'
results.reset_index(inplace=True)
results
# Out:
#     newhead            page_id  like_count  haha_count  love_count  \
# 0   2019-03  11546999983137268        5809           0           0
# 1   2019-04  22205769198340900       22101           0           0
# 2   2019-05  26646923038009080        8069           0           0
# 3   2019-06  18652846126606356       11002           0           0
# 4   2019-07  21317538430407264        8710           0           0
# 5   2019-08  20429307662473628       16075           0           0
# 6   2019-09  18652846126606356        7612           0           0
# 7   2019-10  19541076894539992        8532           0           0
# 8   2019-11  14211692286938176        7068           0           0
# 9   2019-12  14211692286938176       11605           0           0
# 10  2020-01  12435230751070904        7762           0           0
#
#     angry_count  sad_count  wow_count  comment_count  share_count  post_hour
# 0             0          0          0            509           85        211
# 1             0          0          0           1035          291        356
# 2             0          0          0            725          150        409
# 3             0          0          0            306          298        287
# 4             0          0          0            469          297        332
# 5             0          0          0            444          342        347
# 6             0          0          0            366          356        323
# 7             0          0          0            327          239        321
# 8             0          0          0            825          317        210
# 9             0          0          0            671          277        222
# 10            0          0          0            293          251        196

# %%
results['newhead'].map(str)
# Out:
# 0     2019-03
# 1     2019-04
# 2     2019-05
# 3     2019-06
# 4     2019-07
# 5     2019-08
# 6     2019-09
# 7     2019-10
# 8     2019-11
# 9     2019-12
# 10    2020-01
# Name: newhead, dtype: object

# %%
#發文時間分佈
post_time = lo[['post_id','post_hour']].groupby('post_hour').count()
post_time.index.name = 'post_hour'
post_time.reset_index(inplace = True)
post_time
# Out:
#     post_hour  post_id
# 0           0        1
# 1           5        1
# 2           6        2
# 3           7        2
# 4           8        3
# 5           9       11
# 6          10       18
# 7          11       23
# 8          12        6
# 9          13        2
# 10         14       15
# 11         15       48
# 12         16       27
# 13         17       45
# 14         18        9
# 15         19        3
# 16         20        6
# 17         21        3

# %%
# 以圖表呈現時間分佈
import matplotlib.pyplot as plt

labels = post_time['post_hour'].map(str)
width = 0.5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax.bar(labels, post_time['post_id'])

plt.show()

# %%
#整年貼文數量分佈
whole_year = lo[['post_id','month_year']].groupby('month_year').count()
whole_year.index.name = 'month_year'
whole_year.reset_index(inplace=True)
whole_year
# Out:
#    month_year  post_id
# 0     2019-03       13
# 1     2019-04       25
# 2     2019-05       30
# 3     2019-06       21
# 4     2019-07       24
# 5     2019-08       23
# 6     2019-09       21
# 7     2019-10       22
# 8     2019-11       16
# 9     2019-12       16
# 10    2020-01       14

# %%
#畫出整年貼文分佈
labels = results['newhead'].map(str)


fig, ax = plt.subplots()
fig.set_size_inches(15, 8)
ax.bar(labels, whole_year['post_id'])

plt.show()

# %%
#按讚、分享、留言分佈
import matplotlib.pyplot as plt

labels = results['newhead'].map(str)
width = 0.5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax.bar(labels, results['like_count'], width, label='like_count')
ax.bar(labels, results['share_count'], width, label='share_count', bottom=results['like_count'])
ax.bar(labels, results['comment_count'], width, label='comment_count', bottom=results['share_count']+results['like_count'])

ax.legend()

plt.show()

# %%
#個別攤開以折線檢視
labels = results['newhead'].map(str)
width = 0.5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax.plot(labels, results['like_count'])
ax.plot(labels, results['share_count'])
ax.plot(labels, results['comment_count'])

ax.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## 第十屆立委選舉日，民國109年（2020年）1月11號舉行，但為什麼2019年4月跟8月有較高的觸及？

# %%
April = lo[lo.month_year == "2019-04"]

# %%
results_apl  = April.groupby('new_date').sum()
results_apl.index.name = 'new_date'
results_apl.reset_index(inplace=True)
results_apl
# Out:
#       new_date           page_id  like_count  haha_count  love_count  \
# 0   2019-04-01   888230767933636         132           0           0
# 1   2019-04-02  1776461535867272         322           0           0
# 2   2019-04-04   888230767933636        1922           0           0
# 3   2019-04-05   888230767933636        2211           0           0
# 4   2019-04-08   888230767933636          71           0           0
# 5   2019-04-09   888230767933636         879           0           0
# 6   2019-04-11   888230767933636        1889           0           0
# 7   2019-04-12   888230767933636        1669           0           0
# 8   2019-04-13   888230767933636        2827           0           0
# 9   2019-04-14   888230767933636         282           0           0
# 10  2019-04-15   888230767933636         158           0           0
# 11  2019-04-16   888230767933636         126           0           0
# 12  2019-04-17  1776461535867272        2577           0           0
# 13  2019-04-20   888230767933636        6107           0           0
# 14  2019-04-22   888230767933636         116           0           0
# 15  2019-04-23   888230767933636         130           0           0
# 16  2019-04-24  1776461535867272         190           0           0
# 17  2019-04-26   888230767933636          47           0           0
# 18  2019-04-28   888230767933636         222           0           0
# 19  2019-04-29  1776461535867272         110           0           0
# 20  2019-04-30   888230767933636         114           0           0
#
#     angry_count  sad_count  wow_count  comment_count  share_count  post_hour
# 0             0          0          0             10            3         11
# 1             0          0          0             25            3         31
# 2             0          0          0             39           14          9
# 3             0          0          0             31           27          8
# 4             0          0          0              4            2         17
# 5             0          0          0             60           29         14
# 6             0          0          0            105           53         16
# 7             0          0          0             86           23         15
# 8             0          0          0             64           15         17
# 9             0          0          0             20            2         10
# 10            0          0          0             11            5         13
# 11            0          0          0              5            9         14
# 12            0          0          0             96           33         28
# 13            0          0          0            333           49         11
# 14            0          0          0             14            2         15
# 15            0          0          0              4            2         11
# 16            0          0          0             71            2         30
# 17            0          0          0             24            2         15
# 18            0          0          0             13           11         19
# 19            0          0          0              3            3         37
# 20            0          0          0             17            2         15

# %%
#畫圖 看整個月按讚、分享、評論的流量
labels = results_apl['new_date'].map(str)

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax.plot(labels, results_apl['like_count'])
ax.plot(labels, results_apl['share_count'])
ax.plot(labels, results_apl['comment_count'])

ax.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.
